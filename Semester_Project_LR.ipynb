# %%
pca_data <- read.csv("./pca_6_transformed.csv")

# %%
head(pca_data)
# Out:
#   X principal.component.1 principal.component.2 principal.component.3
# 1 0  0.21753142           -0.1317026            -0.08802903
# 2 1 -0.32129307            0.6264234            -0.33736871
# 3 2 -0.02471789            0.1642506             0.11228768
# 4 3 -1.18295941            0.1016878            -0.28532946
# 5 4 -0.05753318            0.2531571            -0.04411924
# 6 5  0.12009359            0.0294906            -0.18151393
#   principal.component.4 principal.component.5 principal.component.6 popularity
# 1 -0.15886922            0.05921683            0.008189202          73
# 2 -0.03809619           -0.26324805           -0.152888443          55
# 3  0.01262224           -0.36763012           -0.276928230          57
# 4 -0.04272990           -0.34474774           -0.203614860          71
# 5 -0.02002454           -0.25556288           -0.241788460          82
# 6 -0.16010119            0.07854730           -0.091444277          58

# %%
dim(pca_data)
# Out:
# [1] 62392     8

# %%
pca_mlr <- lm(formula = popularity ~ principal.component.1 + principal.component.2
              + principal.component.3 + principal.component.4 + principal.component.5
              + principal.component.6, data = pca_data)

# %%
summary(pca_mlr)
# Out:
# Call:
# lm(formula = popularity ~ principal.component.1 + principal.component.2 +
#     principal.component.3 + principal.component.4 + principal.component.5 +
#     principal.component.6, data = pca_data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -28.968 -12.193  -0.878  10.599  55.880
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)            42.88712    0.05845 733.801  < 2e-16 ***
# principal.component.1   1.73558    0.12253  14.165  < 2e-16 ***
# principal.component.2  -0.25130    0.15488  -1.623    0.105
# principal.component.3  -1.30445    0.18687  -6.981 2.97e-12 ***
# principal.component.4   1.88206    0.20165   9.333  < 2e-16 ***
# principal.component.5  -1.01153    0.25136  -4.024 5.72e-05 ***
# principal.component.6 -13.61970    0.27428 -49.656  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 14.6 on 62385 degrees of freedom
# Multiple R-squared:  0.04326,	Adjusted R-squared:  0.04317
# F-statistic: 470.2 on 6 and 62385 DF,  p-value: < 2.2e-16
