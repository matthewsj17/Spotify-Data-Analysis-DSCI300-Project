# %%
pca_data <- read.csv("./pca_6_transformed.csv")

# %%
head(pca_data)
# Out:
#   X principal.component.1 principal.component.2 principal.component.3
# 1 0 -0.23618957           -0.08821347           -0.158109325
# 2 1  0.69622375           -0.35196883           -0.047790538
# 3 2  0.15776430            0.10839604            0.009121431
# 4 3  0.76060207           -0.26814624           -0.019441915
# 5 4  0.24102905           -0.05126187           -0.025798081
# 6 5 -0.05259408           -0.18576978           -0.162583997
#   principal.component.4 principal.component.5 principal.component.6 popularity
# 1  0.05689133            0.01120063            0.322882177          73
# 2 -0.23681882           -0.17202754            0.007176901          55
# 3 -0.34747442           -0.29490550            0.178612785          57
# 4 -0.38510888           -0.19271674           -0.156443379          71
# 5 -0.23210486           -0.25825074            0.088178862          82
# 6  0.08534993           -0.09018481            0.170720947          58

# %%
dim(pca_data)
# Out:
# [1] 62392     8

# %%
pca_mlr <- lm(formula = popularity ~ principal.component.1 + principal.component.2
              + principal.component.3 + principal.component.4 + principal.component.5
              + principal.component.6, data = pca_data)

# %%
summary(pca_mlr)
# Out:
# Call:
# lm(formula = popularity ~ principal.component.1 + principal.component.2 +
#     principal.component.3 + principal.component.4 + principal.component.5 +
#     principal.component.6, data = pca_data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -32.911 -12.072  -1.026  10.440  55.658
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)            42.88712    0.05807 738.599  < 2e-16 ***
# principal.component.1  -1.54550    0.14077 -10.979  < 2e-16 ***
# principal.component.2  -1.35839    0.18557  -7.320 2.51e-13 ***
# principal.component.3   1.79278    0.20021   8.955  < 2e-16 ***
# principal.component.4  -0.25289    0.24824  -1.019    0.308
# principal.component.5 -13.79430    0.27197 -50.720  < 2e-16 ***
# principal.component.6  11.62296    0.39899  29.131  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 14.5 on 62385 degrees of freedom
# ...

# %% [markdown]
# removing time sig helped slightly, not by much.
